# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/apj0007/PrawnView/blob/master/ImplementacionLecturaMuestraDeImagen.ipynb)

# %%
# !git clone https://github.com/apj0007/PrawnView

# instalación de opencv y skeleton
# !apt-get -qq install -y libsm6 libxext6 && pip install -q -U opencv-python
import cv2

from scipy import ndimage
import numpy as np
from PIL import Image
import math
import matplotlib.pyplot as plt 

from skimage.io import imread, imshow
from skimage.filters import threshold_otsu
from skimage import io,color,util
from skimage.morphology import skeletonize,skeletonize_3d
from skimage.color import rgb2lab

from skimage.transform import (hough_line, hough_line_peaks,probabilistic_hough_line)
from skimage.feature import canny
# Out:
# fatal: destination path 'PrawnView' already exists and is not an empty directory.

# %%
# !ls PrawnView/ProcesadoImagen
# Out:
# _init_.py  LeerMostrar.py  ProcesadoImagenAutomatico.py

# %%
from PrawnView.ProcesadoImagen.LeerMostrar import LeerMostrar
from PrawnView.ProcesadoImagen.ProcesadoImagenAutomatico import ProcesadoImagenAutomatico
from PrawnView.descargar_extraer_zip import extraer_zip,descargar_zip_url
ProcesadoImagenAutomatico.ProcesadoImagenAutomaticoo('1_1.jpg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-07037c4027dc> in <module>()
#       2 from PrawnView.ProcesadoImagen.ProcesadoImagenAutomatico import ProcesadoImagenAutomatico
#       3 from PrawnView.descargar_extraer_zip import extraer_zip,descargar_zip_url
# ----> 4 ProcesadoImagenAutomatico.ProcesadoImagenAutomaticoo('1_1.jpg')
#
# TypeError: ProcesadoImagenAutomaticoo() missing 1 required positional argument: 'img'

# %%
LeerMostrar.leer_mostrar_imagen('1_1.jpg')
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
# ...

# %%
from PrawnView.descargar_extraer_zip import extraer_zip,descargar_zip_url
zipname=descargar_zip_url("https://github.com/apj0007/PrawnView/raw/master/docs/img/Melanosis.zip")
extraer_zip(zipname)

zipname=descargar_zip_url("https://github.com/apj0007/PrawnView/raw/master/docs/img/FOTOS%20TALLAS.zip")
extraer_zip(zipname)

zipname=descargar_zip_url("https://github.com/apj0007/PrawnView/raw/master/docs/img/Pareja.zip")
extraer_zip(zipname)

zipname=descargar_zip_url("https://github.com/apj0007/PrawnView/raw/master/docs/img/ind_internet.zip")
extraer_zip(zipname)

zipname=descargar_zip_url("https://github.com/apj0007/PrawnView/raw/master/docs/img/im_3.zip")
extraer_zip(zipname)
# Out:
# Descargando... Melanosis.zip
# Descargado correctamente. Melanosis.zip
# Melanosis.zip True
# <ZipInfo filename='M_1.8.jpg' compress_type=deflate external_attr=0x20 file_size=889857 compress_size=885966>
# Error
# Descargando... FOTOS%20TALLAS.zip
# Descargado correctamente. FOTOS%20TALLAS.zip
# FOTOS%20TALLAS.zip True
# <ZipInfo filename='8.1.JPG' compress_type=deflate external_attr=0x20 file_size=957790 compress_size=947105>
# Error
# Descargando... Pareja.zip
# Descargado correctamente. Pareja.zip
# Pareja.zip True
# <ZipInfo filename='a.png' compress_type=deflate external_attr=0x20 file_size=1796507 compress_size=1796750>
# Error
# Descargando... ind_internet.zip
# Descargado correctamente. ind_internet.zip
# ind_internet.zip True
# <ZipInfo filename='2_1.png' compress_type=deflate external_attr=0x20 file_size=22536 compress_size=22327>
# Error
# Descargando... im_3.zip
# Descargado correctamente. im_3.zip
# im_3.zip True
# ...

# %%
# !ls
# Out:
# 10.1.JPG  6.3.JPG	   c.png	       M_12.1.jpg  M_8.jpg
# 10.JPG	  6.4.JPG	   datalab	       M_12.jpg    M_9.1.jpg
# 1_1.jpg   6.7.JPG	   d.png	       M_13.JPG    M_9.jpg
# 1_2.jpg   8.1.JPG	   e.png	       M_1.8.jpg   Melanosis.zip
# 1_3.jpg   8.3.JPG	   FOTOS%20TALLAS.zip  M_1.9.jpg   Pareja.zip
# 1_4.jpg   8.4.JPG	   f.png	       M_22.jpg    prawnvieW
# 1.jpg	  8.7 - copia.JPG  g.png	       M_4.1.jpg   x2.JPG
# 2_1.png   8.7.JPG	   im_3.zip	       M_6.1.jpg   x5.JPG
# 4.1.JPG   8.8.jpg	   ind_internet.zip    M_6.jpg	   x6.JPG
# 4.2.JPG   8.JPG		   M_10_1.jpg	       M_8.1.jpg   x7.1.JPG
# 4.JPG	  a.png		   M_10.jpg	       M_8.2.jpg   x7.JPG
# 6.2.JPG   b.png		   M_1.11.jpg	       M_8.3.jpg

# %%
  img9 =imread('1_1.jpg')

# %% [markdown]
# dietapordientes investigar  en analisis el mediador y la fachada.
# qt en version open source
# imagenes propias
# estudiar mediador que llama a fachada y a los paneles del interfaz grafico
# bounding_box se saca la region nos devuelve los puntos y calculo la distancia eulcidea a cada uno de los puntos del skeleton despues de unir las lineas
