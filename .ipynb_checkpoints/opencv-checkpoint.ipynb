# %%
# %matplotlib inline


from skimage import io # necesario para leer imágenes
import matplotlib.pyplot as plt #matplotlib es necesario para mostrar gráficos
import matplotlib.cm as cm
import matplotlib.patches as mpatches
import numpy
import cv2

# %%
#Cargar imagen
img=cv2.imread("C:/Users/oficina31/WorkspaceAnaconda/Prawn.jpg")

#Cargar imagen en escala de grises
#img=cv2.imread("C:/Users/oficina31/WorkspaceAnaconda/Prawn.jpg",cv2.IMREAD_GREYSCALE)

# %%
#Guardar una imagen
#img=cv2.imwrite("IMG_GUARD_CV2",img)

# %%
#Mostrar la imagen,esperar a pulsar una tecla y cerrar todas  las ventanas
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def matplotlib():

    img=cv2.imread("C:/Users/oficina31/WorkspaceAnaconda/Prawn.jpg")
    plt.imshow(img)
    plt.xticks([]), plt.yticks([])
    plt.show()

    return

# %%
matplotlib()

# %%
def camaraWeb():    
    cap = cv2.VideoCapture(0)

    while(True):
        # Captura frame por frame
        ret,frame = cap.read()   
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)  
        cv2.imshow('frame',frame)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    # When everything done, release the capture
    cap.release()
    cv2.destroyAllWindows()

# %%
camaraWeb()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-d569d5b2f4e3> in <module>()
# ----> 1 camaraWeb()
#
# <ipython-input-6-bb427c368525> in camaraWeb()
#       5         # Captura frame por frame
#       6         ret,frame = cap.read()
# ----> 7         gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#       8         cv2.imshow('frame',frame)
#       9
#
# error: C:\bld\opencv_1510966006874\work\opencv-3.3.0\modules\imgproc\src\color.cpp:10638: error: (-215) scn == 3 || scn == 4 in function cv::cvtColor

# %%
def cargarVideo():       
    cap = cv2.VideoCapture("C:/Users/administrador.ADMINISTRACION/Videos/Movavi Video Editor/Media Content/Video/Stars.avi")
    while(cap.isOpened()):        
        ret, frame = cap.read()            
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) 
        cv2.imshow('frame',gray)            
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break    
    cap.release()
    cv2.destroyAllWindows()

# %%
cargarVideo()

# %%
def guardarVideo():    
    cap = cv2.VideoCapture(0)
    # Definimos el codec a usar
    fourcc = cv2.VideoWriter_fourcc(*'XVID')    
    out = cv2.VideoWriter('videos/output.avi',fourcc, 20.0, (640,480))    
    while(cap.isOpened()):
        ret, frame = cap.read()
        if ret==True:
            #frame = cv2.flip(frame,0)               
            out.write(frame)                
            cv2.imshow('frame',frame)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        else:
            break
    # Cerramos la conexion
    cap.release()
    out.release()
    cv2.destroyAllWindows()

# %%
#guardarVideo()
